# %%
import sys

sys.path.insert(0, "d:/odibi")

from agents.ui import launch
from agents.ui.components.folder_picker import get_cached_embedder

# Pre-load the embedding model BEFORE starting UI
get_cached_embedder()  # This loads the model now, shows progress

# Then launch
launch(working_project="d:/odibi")

# %%
# import sys
# sys.path.insert(0, "D:/odibi")

# from odibi_chat.ui.app import create_app

# app = create_app(
#     project_path="D:/odibi",
#     model="o4-mini",
#     config_path="D:/odibi/.odibi-chat/config.yaml"
# )
# app.launch()

# %%
# try:
#     print("Import successful!")
# except Exception:
#     import traceback
#     traceback.print_exc()
