# %% [markdown]
# # Phase 3 Feature Demo: Story Generator Enhancements
#
# This notebook demonstrates the new **Schema Tracking** and **Data Snapshot** capabilities added to the Story Generator in Phase 3.
#
# We will:
# 1. Create a simple pipeline that modifies the schema (adds columns, pivots data)
# 2. Run the pipeline to generate a story
# 3. Display the generated story to see the new enhancements in action

# %%
import sys
sys.path.insert(0, r'C:\Users\hodibi\OneDrive - Ingredion\Desktop\Repos\Odibi')

# Verify it worked
import odibi
print(f"✅ ODIBI loaded from: {odibi.__file__}")
# Or manually:
# %pip install azure-identity azure-keyvault-secrets adlfs
# Out:
# ✅ ODIBI loaded from: C:\Users\hodibi\OneDrive - Ingredion\Desktop\Repos\Odibi\odibi\__init__.py
# Requirement already satisfied: azure-identity in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: azure-keyvault-secrets in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (4.9.0)
# Requirement already satisfied: adlfs in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (2024.12.0)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from azure-identity) (1.31.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from azure-identity) (41.0.2)
# Requirement already satisfied: msal>=1.30.0 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from azure-identity) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from azure-identity) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from azure-identity) (4.14.0)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from azure-keyvault-secrets) (0.7.2)
# Requirement already satisfied: azure-datalake-store<0.1,>=0.0.53 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from adlfs) (0.0.53)
# Requirement already satisfied: azure-storage-blob>=12.17.0 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from adlfs) (12.23.1)
# Requirement already satisfied: fsspec>=2023.12.0 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from adlfs) (2024.12.0)
# Requirement already satisfied: aiohttp>=3.7.0 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from adlfs) (3.8.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.7.0->adlfs) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.7.0->adlfs) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.7.0->adlfs) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.7.0->adlfs) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.7.0->adlfs) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.7.0->adlfs) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.7.0->adlfs) (1.2.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from azure-core>=1.31.0->azure-identity) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from azure-core>=1.31.0->azure-identity) (1.16.0)
# Requirement already satisfied: cffi in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from azure-datalake-store<0.1,>=0.0.53->adlfs) (1.15.1)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from msal>=1.30.0->azure-identity) (2.4.0)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from msal-extensions>=1.2.0->azure-identity) (2.10.1)
# Requirement already satisfied: pycparser in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from cffi->azure-datalake-store<0.1,>=0.0.53->adlfs) (2.21)
# Requirement already satisfied: pywin32>=226 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from portalocker<3,>=1.4->msal-extensions>=1.2.0->azure-identity) (305.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hodibi\appdata\local\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping c:\Users\hodibi\AppData\Local\anaconda3\Lib\site-packages\semver-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\hodibi\AppData\Local\anaconda3\Lib\site-packages\semver-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\hodibi\AppData\Local\anaconda3\Lib\site-packages\semver-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\hodibi\AppData\Local\anaconda3\Lib\site-packages\semver-2.13.0.dist-info due to invalid metadata entry 'name'

# %%
# Setup - Create a temporary pipeline config
import os
import yaml
from IPython.display import Markdown, display

config = {
    "project": "Schema Tracking Demo",
    "version": "1.0.0",
    "engine": "pandas",
    
    # Connections
    "connections": {
        "local_data": {
            "type": "local",
            "base_path": "./data"
        }
    },
    
    # Story Config
    "story": {
        "connection": "local_data",
        "path": "stories",
        "max_sample_rows": 5,  # Snapshot feature
        "auto_generate": True
    },
    
    # Pipeline Definition
    "pipelines": [
        {
            "pipeline": "schema_evolution_demo",
            "description": "Demonstrates schema changes between nodes",
            "nodes": [
                # Node 1: Create source data
                {
                    "name": "create_source",
                    "description": "Generates initial sales data",
                    "transform": {
                        "steps": [
                            {
                                "sql": """
                                SELECT 
                                    'A' as product, 
                                    'North' as region, 
                                    100 as sales
                                UNION ALL
                                SELECT 'B', 'North', 150
                                UNION ALL
                                SELECT 'A', 'South', 200
                                """
                            }
                        ]
                    }
                },
                
                # Node 2: Add new column (Schema Change!)
                {
                    "name": "enrich_data",
                    "description": "Adds a new column 'tax'",
                    "depends_on": ["create_source"],
                    "transform": {
                        "steps": [
                            # Calculate 10% tax
                            {"sql": "SELECT *, sales * 0.1 as tax FROM create_source"}
                        ]
                    }
                },
                
                # Node 3: Remove column (Schema Change!)
                {
                    "name": "cleanup_data",
                    "description": "Removes the region column",
                    "depends_on": ["enrich_data"],
                    "transform": {
                        "steps": [
                            {"sql": "SELECT product, sales, tax FROM enrich_data"}
                        ]
                    }
                }
            ]
        }
    ]
}

# Write config to file
os.makedirs("data/stories", exist_ok=True)
with open("demo_project.yaml", "w") as f:
    yaml.dump(config, f)
    
print("Created demo_project.yaml")
# Out:
# Created demo_project.yaml

# %%
# Run the pipeline
from odibi.pipeline import PipelineManager

# Initialize manager
manager = PipelineManager.from_yaml("demo_project.yaml")

# Run pipeline
results = manager.run("schema_evolution_demo")

print(f"\nStory generated at: {results.story_path}")
# Out:
# ============================================================
# Running pipeline: schema_evolution_demo
# ============================================================
#
#
# ✅ SUCCESS - schema_evolution_demo
#   Completed: 3 nodes
#   Failed: 0 nodes
#   Duration: 0.08s
#   Story: c:\Users\hodibi\OneDrive - Ingredion\Desktop\Repos\Odibi\walkthroughs\data\stories\schema_evolution_demo_20251119_165610.md
#
# Story generated at: c:\Users\hodibi\OneDrive - Ingredion\Desktop\Repos\Odibi\walkthroughs\data\stories\schema_evolution_demo_20251119_165610.md

# %%
# Display the generated story
if results.story_path:
    with open(results.story_path, "r", encoding="utf-8") as f:
        story_content = f.read()
    
    display(Markdown(story_content))
else:
    print("No story generated!")
# Out:
# # Pipeline Run Story: schema_evolution_demo
#
# **Executed:** 2025-11-19T16:56:10.535762
# **Completed:** 2025-11-19T16:56:10.611748
# **Duration:** 0.08s
# **Status:** ✅ Success
#
# ---
#
# ## Summary
#
# - ✅ **Completed:** 3 nodes
# - ❌ **Failed:** 0 nodes
# - ⏭️ **Skipped:** 0 nodes
# - ⏱️ **Duration:** 0.08s
#
# **Completed nodes:** create_source, enrich_data, cleanup_data
#
# ---
#
# ## Node: create_source
#
# **Status:** ✅ Success
# **Duration:** 0.0336s
#
# **Execution steps:**
# - Applied 1 transform steps
#
# **Output schema:**
# - Columns (3): product, region, sales
# - Rows: 3
#
# **Sample output** (first 3 rows):
#
# | product | region | sales |
# | --- | --- | --- |
# | A | North | 100 |
# | B | North | 150 |
# | A | South | 200 |
#
# ---
#
# ## Node: enrich_data
#
# **Status:** ✅ Success
# **Duration:** 0.0264s
#
# **Execution steps:**
# - Applied 1 transform steps
#
# **Input schema:**
# - Columns (3): product, region, sales
#
# **Sample input** (first 3 rows):
#
# | product | region | sales |
# | --- | --- | --- |
# | A | North | 100 |
# | B | North | 150 |
# | A | South | 200 |
#
# **Output schema:**
# - Columns (4): product, region, sales, tax
#
# **Schema Changes:**
# - 🟢 **Added:** tax
# - Rows: 3
#
# **Sample output** (first 3 rows):
#
# | product | region | sales | tax |
# | --- | --- | --- | --- |
# | A | North | 100 | 10.0 |
# | B | North | 150 | 15.0 |
# | A | South | 200 | 20.0 |
#
# ---
#
# ## Node: cleanup_data
#
# **Status:** ✅ Success
# **Duration:** 0.0160s
#
# **Execution steps:**
# - Applied 1 transform steps
#
# **Input schema:**
# - Columns (4): product, region, sales, tax
#
# **Sample input** (first 3 rows):
#
# | product | region | sales | tax |
# | --- | --- | --- | --- |
# | A | North | 100 | 10.0 |
# | B | North | 150 | 15.0 |
# | A | South | 200 | 20.0 |
#
# **Output schema:**
# - Columns (3): product, sales, tax
#
# **Schema Changes:**
# - 🔴 **Removed:** region
# - Rows: 3
#
# **Sample output** (first 3 rows):
#
# | product | sales | tax |
# | --- | --- | --- |
# | A | 100 | 10.0 |
# | B | 150 | 15.0 |
# | A | 200 | 20.0 |
#
# ---

# %% [markdown]
# ## What to look for:
#
# 1. **Node `enrich_data`**:
#    - Should show `Schema Changes` section
#    - `🟢 Added: tax`
#
# 2. **Node `cleanup_data`**:
#    - Should show `Schema Changes` section
#    - `🔴 Removed: region`
#
# 3. **Sample Data**:
#    - Each node should show a table with the first 5 rows (as configured)
